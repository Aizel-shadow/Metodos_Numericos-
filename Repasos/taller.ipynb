# %%
A2= [
    [1, 2, 3],
    [2, 1, 3],
    [4, 2, 1]
]

n2 = len(A2)
A2_aug = np.hstack((A2, np.eye(n2)))
A2_aug
np.vstack((A2, np.eye(n2)))
_m2_inv = gauss_jordan(A2_aug)
_m2_inv[:,n2:]

# %%
A3= [
    [4, 2, 1],
    [2, 1, 3],
    [1, 3, 4]
]

n3 = len(A3)
A3_aug = np.hstack((A3, np.eye(n3)))
A3_aug
np.vstack((A3, np.eye(n3)))
_m3_inv = gauss_jordan(A3_aug)
_m3_inv[:,n3:]

# %%
A4= [
    [2, 4, 6, 1],
    [4, 7, 5, -6],
    [2, 5, 18, 10],
    [6, 12, 38, 16]
]

# %%
b1= [
 [1],
 [2],
 [4]
]

# %%
b2= [
 [3],
 [-5],
 [2]
]

# %%
b3= [
 [7],
 [8],
 [11]
]

# %%
b1= [
 [1],
 [2],
 [4],
 [5]
]

# %%
b2= [
 [3],
 [-5],
 [2],
 [6]
]

# %%
b3= [
 [7],
 [8],
 [-1],
 [0]
]
