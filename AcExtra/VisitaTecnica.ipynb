# %% [markdown]
# ## ACTIVIDAD EXTRACURRICULAR 1B
#
# ### ***TIPOS DE SESGOS Y FALACIAS***
#
# Nombre: Alegria Isabel Farinango Farinango
#
# Fecha: 01/01/2026

# %% [markdown]
# **Consulta y escriba un informe corto sobre:**
#
# *1. En qué consiste el trabajo de un desarrollador remoto?*
#
# El trabajo de un desarrollador remoto consiste en el diseño, creación, mantenimiento y actualización de aplicaciones de software o sistemas informáticos sin necesidad de estar físicamente en una oficina.
#
# Sus funciones principales incluyen:
#
# * Escritura de código: Utilizar lenguajes de programación para construir soluciones técnicas.
#
# * Gestión autónoma: Utilizar herramientas de gestión de proyectos (como Jira o Trello) y control de versiones (como Git) para coordinarse con equipos globales.
#
# * Comunicación asíncrona: Participar en reuniones virtuales y mantener contacto constante vía chat para asegurar el cumplimiento de objetivos.
#
# * Enfoque en resultados: A diferencia del trabajo presencial, se valora más la entrega de tareas funcionales que el cumplimiento de un horario estricto.
#
# *2. Busque una oferta de trabajo en internet y resuma los requisitos para un trabajo remoto.*
#
# Los requisitos más comunes son:
#
# * Técnicos: Dominio de lenguajes específicos (ej. Python, React, Node.js), experiencia en bases de datos (SQL/NoSQL) y conocimiento de servicios en la nube (AWS, Azure).
#
# * Idiomas: Nivel de inglés avanzado (B2/C1) suele ser indispensable para empresas internacionales.
#
# * Soft Skills: Alta capacidad de autogestión, disciplina, excelente comunicación escrita y resolución de problemas de forma independiente.
#
# * Infraestructura: Conexión a internet estable y un entorno de trabajo adecuado.
#
# *3. Resumen de la empresa InitGrammers.*
#
# InitGrammers es una empresa de desarrollo de software de origen ecuatoriano. Se especializan en:
#
# * Desarrollo de soluciones tecnológicas personalizadas.
#
# * Posiblemente enfocados en servicios de consultoría IT, desarrollo web y móvil.
#
# * Su presencia digital (www.initgrammers.com) sugiere un enfoque moderno hacia la transformación digital de negocios.
#
# *4. Perfil de Henry Villavicencio Catota.*
#
# ![image.png](attachment:image.png)
#
# * Cargo: CEO y Co-Fundador de InitGrammers.
#
# * Educación: Estudió en la Escuela Politécnica Nacional (EPN).
#
# * Experiencia: Además de liderar su propia empresa, tiene vínculos con organizaciones como Mozrest.
#
# * Perfil: Se presenta como un emprendedor tecnológico con formación sólida en ingeniería, enfocado en el liderazgo de equipos de desarrollo y la creación de productos de software.
#
# *5. Lista de preguntas para el invitado.*
#
# * ¿Cuáles fueron los mayores retos al fundar InitGrammers y posicionarla en el mercado de software?
#
# * ¿Qué tecnologías considera esenciales que un desarrollador debe dominar hoy en día para ser competitivo de forma remota?
#
# * ¿Qué consejo le daría a los estudiantes de la EPN que aspiran a emprender en el sector tecnológico?
