# %% [markdown]
# ## [ACTIVIDADES EXTRACURRICULARES]
#
# ### *PYTHON*
#
# Nombre: Alegria Isabel Farinango Farinango
#
# Fecha: 01/11/2025
#
#
# ***[Actividad extracurricular 01] Página web personal***
#
# PONER PIC DE LA PAGINA

# %% [markdown]
# ***[Actividad extracurricular 02] python interactivo***
#
#     Primer Programa
#
# 1.
# ![image.png](attachment:image.png)
#
# 2.
# ![image-2.png](attachment:image-2.png)
#
# Si se añade un ```print()``` adicional, la impresión del código se vera de la siguiente manera, aunque parece que esta vacía no es así.
#
# 3.
#
# ![image-3.png](attachment:image-3.png)
#
# 4.
# Aquí se inserta la barra invertida ```\n``` llamado *carácter de escape*
#
# ![image-4.png](attachment:image-4.png)
#
# Aunque para una mejor visualización, adjunto el código.

# %%
print("La Witsi Witsi Araña\nsubió a su telaraña.")
print()
print("Vino la lluvia\ny se la llevó.")
# Out:
# La Witsi Witsi Araña
# subió a su telaraña.
#
# Vino la lluvia
# y se la llevó.

# %% [markdown]
# 5. El comportamiento de la función ```print()``` sin argumentos y con un argumento.
#
# ![image.png](attachment:image.png)
#
# 6. Argumentos posicionales, donde el argumento está dictado por su posición.
#
# ![image-2.png](attachment:image-2.png)
#
# 7. Argumentos de palabra clave
#
# ![image-3.png](attachment:image-3.png)
#
# 8. Literales - los datos en sí mismos, un literal se refiere a datos cuyos valores están determinados por el literal mismo
#
# ![image-4.png](attachment:image-4.png)
#
# 9. Números octales y hexadecimales
#
# ![image-5.png](attachment:image-5.png)
#
# 10. Codificando Cadenas
#
# ![image-6.png](attachment:image-6.png)
#
# 11. Valores Booleanos
#
# ![image-7.png](attachment:image-7.png)
#
# una parte del álgebra que hace uso de dos valores: True y False, denotados como 1 y 0.
#
# 12.
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)

# %% [markdown]
# ***[Actividad extracurricular 03] python certificado***
