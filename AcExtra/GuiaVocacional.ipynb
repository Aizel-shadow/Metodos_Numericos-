# %% [markdown]
# ## **ACTIVIDAD EXTRACURRICULAR 09**

# %% [markdown]
# ### ***GUÍA VOCACIONAL***
#
# Nombre: Alegria Isabel Farinango Farinango
#
# Fecha: 16/11/2025

# %% [markdown]
# **Objetivo**
#
# * Explorar herramientas digitales relacionadas a la guía vocacional.
#
# **Indicaciones**
#
# * Vea el siguiente video https://www.youtube.com/@RobertMilesAI/videos
#
# * Realice el seguimiento de 80k hours.
#
# * Suba algún tipo de evidencia.

# %% [markdown]
# Bueno este canal se enfoca en la seguridad de la IA y los riesgos asociados con el desarrollo de la IA avanzada, alguno de los videos que me llamaron la atención fueron estos.
#
# *1. "AI Safety Career Advice! (And So Can You!)"*
#
# Trata de ofrecer consejos y orientación profesional para aquellos interesados en hacer una carrera en el campo de la seguridad de la IA. El video anima a la audiencia a considerar cómo pueden contribuir a este campo crucial.
#
#
# *2. "AI Ruined My Year"*
#
# Una reflexión personal y detallada sobre el impacto y las preocupaciones de Robert Miles sobre el estado actual y el desarrollo futuro de la IA. Es probable que explore las razones por las que el tema de la seguridad de la IA le ha causado gran preocupación durante el año, e incluye información sobre cómo la gente puede ayudar en la causa.
#
#
# *3. "Using Dangerous AI, But Safely?"*
#
# Se aborda el complejo problema de si es posible mantener bajo control a una IA poderosa y potencialmente peligrosa, incluso sugiriendo la posibilidad de usar la propia IA para este propósito (una forma de control o alineamiento). El video se centra en el desafío de la contención y la seguridad de los sistemas de IA avanzados.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Referencia bibliográfica**
#
# - *Robert Miles AI Safety. (n.d.). Home [Página de canal de YouTube]. Recuperado el [Día de hoy, p. ej., 17 de noviembre de 2025], de https://www.youtube.com/@RobertMilesAI/videos*
