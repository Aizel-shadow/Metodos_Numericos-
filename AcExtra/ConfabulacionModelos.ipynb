# %% [markdown]
# ## **ACTIVIDAD EXTRACURRICULAR 10**

# %% [markdown]
# ### ***Confabulación en los Modelos de Lenguaje***
#
# Nombre: Alegria Isabel Farinango Farinango
#
# Fecha: 23/11/2025
#
# #### Indicaciones
#
# Utilizando cualquier modelo de lenguaje de gran tamaño LLM (i.e. ChatGPT, Claude, Gemini, etc) encuentre 3 ejemplos en donde el modelo de lenguaje dé una respuesta incorrecta.
#
# La IA escogida fue ChatGpt
#
# 1. ![image.png](attachment:image.png)
#
# ---
#
# 2. ![image-2.png](attachment:image-2.png)
#
# ---
#
# 3. ![image-3.png](attachment:image-3.png)
